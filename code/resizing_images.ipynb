# %%
# !pip install opencv-python
import cv2 as cv
from google.colab.patches import cv2_imshow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 17.9 MB/s eta 0:00:00
# ...

# %%
import shutil

# %%
img1= cv.imread('/content/production_drawings/img100.jpg')

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=623x606>

# %%
h,w,c= img1.shape

# %%
h,w
# Out:
# (606, 623)

# %%
def img_resize(img):
  img= cv.resize(img,(600,400))
  return img

# %%
resized_img= img_resize(img1)
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
source= '/content/production_drawings'
destination= '/content/destination'
import os
import cv2 as cv

# %%
for filename in os.listdir(source):
  source_path= os.path.join(source,filename)
  ##print(source_path)
  img= cv.imread(source_path)

  if img is not None:
    resize_img= cv.resize(img ,(600,400))
    destination_path= os.path.join(destination,filename)
    cv.imwrite(destination_path,resize_img)
  else:
    print('Image not found')

# %%
import shutil
shutil.make_archive('destination','zip','/content/destination')
# Out:
# '/content/destination.zip'

# %%
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 18.9 MB/s eta 0:00:00
# ...
